# %%
# Data Manipulation
import numpy as np
import pandas as pd

# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
heart_df= pd.read_csv('heart1.csv')

# %%
heart_df = pd.DataFrame(heart_df)

# %%
heart_df
# Out:
#       age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  \
# 0    63.0  1.0  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3
# 1    37.0  1.0  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5
# 2    41.0  0.0  1.0   130.0  204.0  NaN      0.0     172.0   0.0      1.4
# 3    56.0  1.0  1.0   120.0  236.0  0.0      NaN       NaN   0.0      0.8
# 4    57.0  0.0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6
# ..    ...  ...  ...     ...    ...  ...      ...       ...   ...      ...
# 298  57.0  0.0  0.0   140.0  241.0  0.0      1.0     123.0   1.0      0.2
# 299  45.0  1.0  3.0   110.0  264.0  0.0      1.0     132.0   0.0      1.2
# 300   NaN  1.0  NaN   144.0  193.0  1.0      1.0     141.0   0.0      3.4
# 301  57.0  1.0  0.0   130.0    NaN  0.0      1.0     115.0   1.0      NaN
# 302   NaN  0.0  1.0   130.0  236.0  0.0      0.0     174.0   0.0      0.0
#
#      slp  caa  thall  output
# 0    0.0  0.0    1.0     1.0
# ...

# %%
heart_df.isnull().sum().sum()
# Out:
# 204

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       288 non-null    float64
#  1   sex       295 non-null    float64
#  2   cp        283 non-null    float64
#  3   trtbps    279 non-null    float64
#  4   chol      285 non-null    float64
#  5   fbs       290 non-null    float64
#  6   restecg   293 non-null    float64
#  7   thalachh  283 non-null    float64
#  8   exng      296 non-null    float64
#  9   oldpeak   290 non-null    float64
#  10  slp       291 non-null    float64
#  11  caa       297 non-null    float64
#  12  thall     291 non-null    float64
#  13  output    277 non-null    float64
# dtypes: float64(14)
# memory usage: 33.3 KB

# %%
heart_df.describe() #DESCRIPTIVE STATISTIC OF ALL NUMERIC COLUMNS ONLY
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  288.000000  295.000000  283.000000  279.000000  285.000000  290.000000
# mean    54.201389    0.681356    1.000000  131.516129  246.957895    0.151724
# std      8.906858    0.466742    1.041684   17.610869   51.950189    0.359373
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.750000    0.000000    0.000000  120.000000  212.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     60.250000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     76.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp        caa  \
# count  293.000000  283.000000  296.000000  290.000000  291.000000  297.00000
# mean     0.522184  149.194346    0.324324    1.044483    1.408935    0.73064
# ...

# %%
heart_df.head()
# Out:
#     age  sex   cp  trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0  63.0  1.0  3.0   145.0  233.0  1.0      0.0     150.0   0.0      2.3  0.0
# 1  37.0  1.0  2.0   130.0  250.0  0.0      1.0     187.0   0.0      3.5  NaN
# 2  41.0  0.0  1.0   130.0  204.0  NaN      0.0     172.0   0.0      1.4  2.0
# 3  56.0  1.0  1.0   120.0  236.0  0.0      NaN       NaN   0.0      0.8  2.0
# 4  57.0  0.0  0.0   120.0  354.0  0.0      1.0     163.0   1.0      0.6  2.0
#
#    caa  thall  output
# 0  0.0    1.0     1.0
# 1  0.0    2.0     1.0
# 2  0.0    2.0     NaN
# 3  0.0    2.0     1.0
# 4  0.0    2.0     1.0

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
# Check for duplicate data
dups = heart_df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

heart_df[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [age, sex, cp, trtbps, chol, fbs, restecg, thalachh, exng, oldpeak, slp, caa, thall, output]
# Index: []

# %%
heart_df.boxplot(column=['age'])
plt.show()

# %%
sns.boxplot(data=heart_df)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.title('Boxplot of Whole Dataset')
plt.show()

# %%
columns_to_clean = ['trtbps','chol', 'thalachh', 'oldpeak']

for column in columns_to_clean:
    # Calculate Q1, Q3, and IQR for the current column
    Q1 = heart_df[column].quantile(0.25)
    Q3 = heart_df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define the lower and upper bounds for outlier removal
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Remove outliers from the current column
    heart_df[column] = np.where((heart_df[column] < lower_bound) | (heart_df[column] > upper_bound),
                                 np.where(heart_df[column] < lower_bound, lower_bound, upper_bound),
                                 heart_df[column])

# %%
sns.boxplot(data=heart_df)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.title('Boxplot of Whole Dataset')
plt.show()

# %%
heart_df["caa"].fillna(heart_df['caa'].mode(), inplace=True)
heart_df["thall"].fillna(heart_df['thall'].mean(), inplace=True)
heart_df["output"].fillna(heart_df['output'].mode(), inplace=True)
heart_df["sex"].fillna(heart_df['sex'].mode(), inplace=True)
heart_df["cp"].fillna(heart_df['cp'].mode(), inplace=True)
heart_df["fbs"].fillna(heart_df['fbs'].mode(), inplace=True)
heart_df["restecg"].fillna(heart_df['restecg'].mode(), inplace=True)
heart_df["exng"].fillna(heart_df['exng'].mode(), inplace=True)

# %%
# Check for missing value in any column
heart_df.isnull().sum()
# Out:
# age         15
# sex          8
# cp          20
# trtbps      24
# chol        18
# fbs         13
# restecg     10
# thalachh    20
# exng         7
# oldpeak     13
# slp         12
# caa          6
# thall        0
# output      26
# dtype: int64

# %%
heart_df['caa'].fillna(heart_df['caa'].mode()[0], inplace=True)

# %%
# Check for missing value in any column
heart_df.isnull().sum()
# Out:
# age         15
# sex          8
# cp          20
# trtbps      24
# chol        18
# fbs         13
# restecg     10
# thalachh    20
# exng         7
# oldpeak     13
# slp         12
# caa          0
# thall        0
# output      26
# dtype: int64

# %%
heart_df['output'].fillna(heart_df['output'].mode()[0], inplace=True) 
heart_df['sex'].fillna(heart_df['sex'].mode()[0], inplace=True) 
heart_df['cp'].fillna(heart_df['cp'].mode()[0], inplace=True) 
heart_df['fbs'].fillna(heart_df['fbs'].mode()[0], inplace=True) 
heart_df['restecg'].fillna(heart_df['restecg'].mode()[0], inplace=True)
heart_df['exng'].fillna(heart_df['exng'].mode()[0], inplace=True)

# %%
# Check for missing value in any column
heart_df.isnull().sum()
# Out:
# age         15
# sex          0
# cp           0
# trtbps      24
# chol        18
# fbs          0
# restecg      0
# thalachh    20
# exng         0
# oldpeak     13
# slp         12
# caa          0
# thall        0
# output       0
# dtype: int64

# %%
median1=heart_df["age"].median()
median2=heart_df["trtbps"].median()
median3=heart_df["chol"].median()
median4=heart_df["thalachh"].median()
median5=heart_df["oldpeak"].median()
median6=heart_df["slp"].median()

# %%
heart_df['age'].replace(np.nan,median1,inplace=True)
heart_df['trtbps'].replace(np.nan,median2,inplace=True)
heart_df['chol'].replace(np.nan,median3,inplace=True)
heart_df['thalachh'].replace(np.nan,median4,inplace=True)
heart_df['oldpeak'].replace(np.nan,median5,inplace=True)
heart_df['slp'].replace(np.nan,median6,inplace=True)

# %%
heart_df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# Renamed name of variables to have a better understanding while working on dataset:
heart_df.rename(columns={
    "age":"Age",
    "sex":"Sex",
    "cp":"ChestPain",
    "trtbps":"RestingBloodPressure",
    "chol":"Cholesterol",
    "fbs":"FastingBloodSugar",
    "restecg":"RestingECG",
    "thalachh":"MaxHeartRate",
    "exng":"ExcerciseAngina",
    "oldpeak":"OldPeak",
    "slp":"STSlope",
    "caa":"nMajorVessels",
    "thall":"Thalium",
    "output":"Status"
}, inplace=True)

# %%
#Changed the integer values of some variables to categorical values based on description of variables:
mappings = {
    'Sex': {
        0: "Female",
        1: "Male"
    },
    'ChestPain': {
        0: "Typical angina",
        1: "Atypical angina",
        2: "Non-anginal pain",
        3: "Asymptomatic"
    },
    "FastingBloodSugar": {
        0:False,
        1:True
    },
    "RestingECG": {
        0:"Normal",
        1:"Abnormality",
        2:"Hypertrophy"
    },
    "ExcerciseAngina": {
        0:"No",
        1:"Yes"
    },
    "STSlope": {
        0:"Upsloping",
        1:"Flat",
        2:"Downsloping"
    },
    "Thalium": {
        0:"Normal",
        1:"Fixed defect",
        2:"Reversible defect",
        3:"Not described"
    },
    "Status": {
        0:"No Disease",
        1:"Heart Disease"
    }
}

# %%
def map_values(x, mapping):
    return mapping.get(x, x)

# %%
heart_df
# Out:
#       Age  Sex  ChestPain  RestingBloodPressure  Cholesterol  \
# 0    63.0  1.0        3.0                 145.0        233.0
# 1    37.0  1.0        2.0                 130.0        250.0
# 2    41.0  0.0        1.0                 130.0        204.0
# 3    56.0  1.0        1.0                 120.0        236.0
# 4    57.0  0.0        0.0                 120.0        354.0
# ..    ...  ...        ...                   ...          ...
# 298  57.0  0.0        0.0                 140.0        241.0
# 299  45.0  1.0        3.0                 110.0        264.0
# 300  55.0  1.0        0.0                 144.0        193.0
# 301  57.0  1.0        0.0                 130.0        240.0
# 302  55.0  0.0        1.0                 130.0        236.0
#
#      FastingBloodSugar  RestingECG  MaxHeartRate  ExcerciseAngina  OldPeak  \
# 0                  1.0         0.0         150.0              0.0      2.3
# 1                  0.0         1.0         187.0              0.0      3.5
# ...

# %% [markdown]
# #Visualization

# %%
sns.distplot(heart_df['Age'],hist_kws=dict(linewidth=1,edgecolor='k'))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13348\2275489320.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart_df['Age'],hist_kws=dict(linewidth=1,edgecolor='k'))
# <Axes: xlabel='Age', ylabel='Density'>

# %%
custom_labels = ['Females', 'Males']

# Count the occurrences of each sex category
sex_counts = heart_df['Sex'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sex_counts, labels=custom_labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Sex')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
cp_count = heart_df['ChestPain'].value_counts()
print(cp_count)
# Out:
# ChestPain
# 0.0    150
# 2.0     84
# 1.0     46
# 3.0     23
# Name: count, dtype: int64

# %%
# Creating a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=cp_count.index, y=cp_count.values, palette="viridis")
plt.title('Count of Unique Values in ChestPain')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13348\2849617644.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cp_count.index, y=cp_count.values, palette="viridis")

# %%
# Plot rest_ecg with respect to sex
plt.figure(figsize=(10, 6))
sns.countplot(data=heart_df, x='RestingECG', hue='Sex', palette='viridis')
plt.title('Resting Electrocardiographic Results by Sex')
plt.xlabel('Resting Electrocardiographic Results')
plt.ylabel('Count')
plt.legend(title='Sex', labels=['Male', 'Female'], loc='upper right')
plt.show()

# %%
#Pairplot of all variables
sns.pairplot(heart_df)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
